# %% [markdown]
# # 1. Abusive Swearing Detection

# %%
import pandas as pd 
import numpy as np
df =pd.read_csv('swad_train_new.csv', encoding="utf8")
df_test =pd.read_csv('swad_test.csv', encoding="utf8")
df
# Out:
#         ID                                              Tweet Label
# 0        0           My bullshit radar is on full force today    No
# 1        1            <USER> Sorry, cut the Bull Shit Please.   Yes
# 2        2  @USER He is gay Heâ€™s a sick pervert he gets ...   Yes
# 3        3  @USER @USER @USER Great. Hereâ€™s how today ha...    No
# 4        4  @USER bitch Iâ€™m in the hood serving junkies ...    No
# ...    ...                                                ...   ...
# 3584  3584  @USER 2/3 You were on TV claiming to be a jour...    No
# 3585  3585  stfu no. I didn't survive through 13 seasons o...    No
# 3586  3586  @USER @USER @USER What the hell has his locati...    No
# 3587  3587  @USER @USER And this isnâ€™t considered hate s...    No
# 3588  3588  @USER Itâ€™d better be on Monday and who the h...    No
#
# [3589 rows x 3 columns]

# %%
df
# Out:
#         ID                                              Tweet Label
# 0        0           My bullshit radar is on full force today    No
# 1        1            <USER> Sorry, cut the Bull Shit Please.   Yes
# 2        2  @USER He is gay Heâ€™s a sick pervert he gets ...   Yes
# 3        3  @USER @USER @USER Great. Hereâ€™s how today ha...    No
# 4        4  @USER bitch Iâ€™m in the hood serving junkies ...    No
# ...    ...                                                ...   ...
# 3584  3584  @USER 2/3 You were on TV claiming to be a jour...    No
# 3585  3585  stfu no. I didn't survive through 13 seasons o...    No
# 3586  3586  @USER @USER @USER What the hell has his locati...    No
# 3587  3587  @USER @USER And this isnâ€™t considered hate s...    No
# 3588  3588  @USER Itâ€™d better be on Monday and who the h...    No
#
# [3589 rows x 3 columns]

# %%
print(len(df))
print(len(df_test))
# Out:
# 3589
# 500

# %%
df['Tweet'] = df['Tweet'].str.lower()
df_test['Tweet'] = df_test['Tweet'].str.lower()

# %%
df
# Out:
#         ID                                              Tweet Label
# 0        0           my bullshit radar is on full force today    No
# 1        1            <user> sorry, cut the bull shit please.   Yes
# 2        2  @user he is gay heâ€™s a sick pervert he gets ...   Yes
# 3        3  @user @user @user great. hereâ€™s how today ha...    No
# 4        4  @user bitch iâ€™m in the hood serving junkies ...    No
# ...    ...                                                ...   ...
# 3584  3584  @user 2/3 you were on tv claiming to be a jour...    No
# 3585  3585  stfu no. i didn't survive through 13 seasons o...    No
# 3586  3586  @user @user @user what the hell has his locati...    No
# 3587  3587  @user @user and this isnâ€™t considered hate s...    No
# 3588  3588  @user itâ€™d better be on monday and who the h...    No
#
# [3589 rows x 3 columns]

# %%
df_test
# Out:
#       ID                                              Tweet Label
# 0      0  @user @user this is the dumbest shit iâ€™ve re...    No
# 1      1  @user @user no fr! people are always on the mo...   Yes
# 2      2    @user @user she can lie in the shit she created   Yes
# 3      3  @user we have the real facts......you suck pus...   Yes
# 4      4  @user @user @user time iâ€™m really starting t...   Yes
# ..   ...                                                ...   ...
# 495  495        @user @user action talks and bullshit walks   Yes
# 496  496  @user are we really supposed to believe the pa...    No
# 497  497  @user @user bitch shut up....cyberpunk was ann...   Yes
# 498  498     chance said f*ck a suit love him #ilovenewyork    No
# 499  499  @user @user chloe shut the fuck up. seriously ...   Yes
#
# [500 rows x 3 columns]

# %%
with open("punctuations.txt", "r") as punctuations: 
    punctuations_list=[]
    for line in punctuations:   
        punc = line.split()
        for i in punc: 
            punctuations_list.append(i)
    print(punctuations_list)
# Out:
# ["'", '"', '!', '#', '$', '%', '&', '(', ')', '*', '+', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
punc_list = []
for row in df['Tweet']:
    r=""
    for char in row:
        if char in punctuations_list:
            char = " "+char+" "
            r = r+char
        else:
            r = r+char            
    punc_list.append(r)
punc_ = pd.Series(punc_list)
df['Tweet'] = punc_

# %%
df
# Out:
#         ID                                              Tweet Label
# 0        0           my bullshit radar is on full force today    No
# 1        1       < user >  sorry, cut the bull shit please .    Yes
# 2        2   @ user he is gay heâ€™s a sick pervert he get...   Yes
# 3        3   @ user  @ user  @ user great .  hereâ€™s how ...    No
# 4        4   @ user bitch iâ€™m in the hood serving junkie...    No
# ...    ...                                                ...   ...
# 3584  3584   @ user 2 / 3 you were on tv claiming to be a ...    No
# 3585  3585  stfu no .  i didn ' t survive through 13 seaso...    No
# 3586  3586   @ user  @ user  @ user what the hell has his ...    No
# 3587  3587   @ user  @ user and this isnâ€™t considered ha...    No
# 3588  3588   @ user itâ€™d better be on monday and who the...    No
#
# [3589 rows x 3 columns]

# %%
punc_list = []
for row in df_test['Tweet']:
    r=""
    for char in row:
        if char in punctuations_list:
            char = " "+char+" "
            r = r+char
        else:
            r = r+char            
    punc_list.append(r)
punc_ = pd.Series(punc_list)
df_test['Tweet'] = punc_

# %%
df_test
# Out:
#       ID                                              Tweet Label
# 0      0   @ user  @ user this is the dumbest shit iâ€™v...    No
# 1      1   @ user  @ user no fr !  people are always on ...   Yes
# 2      2   @ user  @ user she can lie in the shit she cr...   Yes
# 3      3   @ user we have the real facts .  .  .  .  .  ...   Yes
# 4      4   @ user  @ user  @ user time iâ€™m really star...   Yes
# ..   ...                                                ...   ...
# 495  495     @ user  @ user action talks and bullshit walks   Yes
# 496  496   @ user are we really supposed to believe the ...    No
# 497  497   @ user  @ user bitch shut up .  .  .  . cyber...   Yes
# 498  498  chance said f * ck a suit love him  # ilovenew...    No
# 499  499   @ user  @ user chloe shut the fuck up .  seri...   Yes
#
# [500 rows x 3 columns]

# %%
with open("stopwords.txt", "r") as stopwords: 
    stopwords_list=[]
    for line in stopwords:   
        stopword = line.split()
        for i in stopword: 
            stopwords_list.append(i)
    print(stopwords_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
len(stopwords_list)
# Out:
# 179

# %%
dflist_stopwords = []
for row in df['Tweet']:
    r=""
    for word in row.split():
        if word not in stopwords_list:
            r = r+word  
            r = r + " "
    print(r.rstrip())
    dflist_stopwords.append(r.rstrip())
#df_tweet = pd.Series(dflist_stopwords)
df['Tweet'] = pd.Series(dflist_stopwords)
# Out:
# bullshit radar full force today
# < user > sorry, cut bull shit please .
# @ user gay heâ€™s sick pervert gets nerves
# @ user @ user @ user great . hereâ€™s today gone : floris wanted spank . leah wanted stab . curtis wonâ€™t back . adam still looks great 67 however old fuck . . . kl bigger dick sheâ€™s . . . heðÿ¤”
# @ user bitch iâ€™m hood serving junkies maybach ! ! ! ! ðÿ˜‚ðÿ˜‚
# @ user @ user ciara stopped much dumb ass shit god bless woman
# < user > nah bruh, try best hoodie ever . ' shit goes ' sex tho
# @ user @ user nonsense . ford campaign . damn fine job . good see politician keep promises push things thru get done . conservative party plenty depth representing ontarians quit
# @ user @ user @ user give fucking break . liberals selective false outrage . turd president gets rightfully railed saying, grab pussy decades hollyweird gets pass saying fuck shit
# @ user iâ€™m finna say fuck get crispy ass jogging suitðÿ˜‚ðÿ˜‚
# ...

# %%
df
# Out:
#         ID                                              Tweet Label
# 0        0                    bullshit radar full force today    No
# 1        1             < user > sorry, cut bull shit please .   Yes
# 2        2         @ user gay heâ€™s sick pervert gets nerves   Yes
# 3        3  @ user @ user @ user great . hereâ€™s today go...    No
# 4        4  @ user bitch iâ€™m hood serving junkies maybac...    No
# ...    ...                                                ...   ...
# 3584  3584  @ user 2 / 3 tv claiming journalist kagan sitt...    No
# 3585  3585  stfu . ' survive 13 seasons hell hospital shit...    No
# 3586  3586  @ user @ user @ user hell location time shooti...    No
# 3587  3587  @ user @ user isnâ€™t considered hate speech l...    No
# 3588  3588  @ user itâ€™d better monday hell slow walk dic...    No
#
# [3589 rows x 3 columns]

# %%
dflist_stopwords = []
for row in df_test['Tweet']:
    r=""
    for word in row.split():
        if word not in stopwords_list:
            r = r+word  
            r = r + " "
    print(r.rstrip())
    dflist_stopwords.append(r.rstrip())
#df_tweet = pd.Series(dflist_stopwords)
df_test['Tweet'] = pd.Series(dflist_stopwords)
# Out:
# @ user @ user dumbest shit iâ€™ve read since slent morning reading trump tweets .
# @ user @ user fr ! people always bullshit & amp ; iâ€™m postponing missing anything else another person canâ€™t get shit together . else fails go & amp ; tbh end better time anyway
# @ user @ user lie shit created
# @ user real facts . . . . . . suck pussy grabber mother fucker
# @ user @ user @ user time iâ€™m really starting hate word . . . . time world open mouth . . . really shut time ! enough left . . . . liberals bull shit time ! case ! actually time
# @ user niggaz buying pussy bitches trying buy love . . .
# whoa spirit guides lurking window, never fit frame invented gringo
# else obnoxious ass come back star trek 4, nobody wants . < url >
# beat goin, take pill disappear . drinking beer, tryin get fuck . # jawndough # editgod < user >
# @ user comey pissed us constitution . . rat needs go away face consequences
# @ user hope itâ€™s full pot holes smells like shit
# ...

# %%
df_test
# Out:
#       ID                                              Tweet Label
# 0      0  @ user @ user dumbest shit iâ€™ve read since s...    No
# 1      1  @ user @ user fr ! people always bullshit & am...   Yes
# 2      2                     @ user @ user lie shit created   Yes
# 3      3  @ user real facts . . . . . . suck pussy grabb...   Yes
# 4      4  @ user @ user @ user time iâ€™m really startin...   Yes
# ..   ...                                                ...   ...
# 495  495          @ user @ user action talks bullshit walks   Yes
# 496  496  @ user really supposed believe party violent l...    No
# 497  497  @ user @ user bitch shut . . . . cyberpunk ann...   Yes
# 498  498        chance said f * ck suit love # ilovenewyork    No
# 499  499  @ user @ user chloe shut fuck . seriously get ...   Yes
#
# [500 rows x 3 columns]

# %% [markdown]
# We cannot use df to train and df_test to test since they are use tf-idf to generate the columns and they will have different number of columns.
# We can split train and test after we vectorize the text data

# %%
data = df.append(df_test, ignore_index=True)

# %%
data.shape
# Out:
# (4089, 3)

# %%
#tf-idf vectorization
def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict
def computeIDF(documents):
    import math
    N = len(documents)    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

def tfidfVectorize(df_col):
    uniqueWords=""
    bagOfWords_list=[]
    for doc in df_col:
        bagOfWords = doc.split(' ')
        bagOfWords_list.append(bagOfWords)
        uniqueWords = set(bagOfWords).union(uniqueWords)
    #print(uniqueWords)
    numOfWords_list=[]
    for bagOfWords in bagOfWords_list:
        numOfWords = dict.fromkeys(uniqueWords, 0)
        for word in bagOfWords:
            numOfWords[word] += 1
        numOfWords_list.append(numOfWords)
    tf_list=[]
    for i in range(len(bagOfWords_list)):
        tf_ = computeTF(numOfWords_list[i], bagOfWords_list[i])
        tf_list.append(tf_)
    idf_ = computeIDF(numOfWords_list)
    tfidf_list=[]
    for i in range(len(tf_list)):
        tfidf_ = computeTFIDF(tf_list[i], idf_)
        tfidf_list.append(tfidf_)
    df_tfidf = pd.DataFrame(tfidf_list)
    return df_tfidf

# %%
def labelEncode(df_col):
    labels = set() #find all labels in each categorical column
    for i in df_col:
        labels.add(i)
    label_dictionary = {}
    #create a dictionary that has numbers(from 0, number of labels in that column -1) as values and labels as key
    for v,k in enumerate(sorted(labels)):
        label_dictionary[k]=v
    #apply numbers for labels using the dictionary created
    df_label = df_col.apply(lambda x: label_dictionary[x])
    return df_label

# %%
X_ = tfidfVectorize(data['Tweet'])

# %%
y_ = labelEncode(data['Label'])

# %%
def testtrain_split(X, y, test_size=0.2):

    i = int((1 - test_size) * X.shape[0]) 
    o = np.random.permutation(X.shape[0])
    
    X_train, X_test = np.split(np.take(X,o,axis=0), [i])
    y_train, y_test = np.split(np.take(y,o), [i])
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = testtrain_split(X_, y_, test_size=0.2)

# %%
class LogisticRegression():
    def __init__(self):
        self.losses = []
        self.train_accuracies = []

    def fit(self, x, y, epochs):
        x = self._transform_x(x)
        y = self._transform_y(y)

        self.weights = np.zeros(x.shape[1])
        self.bias = 0

        for i in range(epochs):
            x_dot_weights = np.matmul(self.weights, x.transpose()) + self.bias
            pred = self._sigmoid(x_dot_weights)
            loss = self.compute_loss(y, pred)
            error_w, error_b = self.compute_gradients(x, y, pred)
            self.update_model_parameters(error_w, error_b)

            pred_to_class = [1 if p > 0.5 else 0 for p in pred]
            self.train_accuracies.append(np.sum(np.equal(y, pred_to_class)) / len(y))
            self.losses.append(loss)

    def compute_loss(self, y_true, y_pred):
        # binary cross entropy
        y_zero_loss = y_true * np.log(y_pred + 1e-9)
        y_one_loss = (1-y_true) * np.log(1 - y_pred + 1e-9)
        return -np.mean(y_zero_loss + y_one_loss)

    def compute_gradients(self, x, y_true, y_pred):
        # derivative of binary cross entropy
        difference =  y_pred - y_true
        gradient_b = np.mean(difference)
        gradients_w = np.matmul(x.transpose(), difference)
        gradients_w = np.array([np.mean(grad) for grad in gradients_w])

        return gradients_w, gradient_b

    def update_model_parameters(self, error_w, error_b):
        self.weights = self.weights - 0.1 * error_w
        self.bias = self.bias - 0.1 * error_b

    def predict(self, x):
        x_dot_weights = np.matmul(x, self.weights.transpose()) + self.bias
        probabilities = self._sigmoid(x_dot_weights)
        return [1 if p > 0.5 else 0 for p in probabilities]

    def _sigmoid(self, x):
        return np.array([self._sigmoid_function(value) for value in x])

    def _sigmoid_function(self, x):
        if x >= 0:
            z = np.exp(-x)
            return 1 / (1 + z)
        else:
            z = np.exp(x)
            return z / (1 + z)

    def _transform_x(self, x):
        x = x
        return x.values

    def _transform_y(self, y):
        y = y
        return y.values.reshape(y.shape[0], 1)

# %%
Logregmodel = LogisticRegression()

# %%
Logregmodel.fit(X_train,y_train,1000)

# %%
pred_y = Logregmodel.predict(X_test)

# %%
print('accuracy -> {}'.format(sum(pred_y == y_test) / y_test.shape[0]))
# Out:
# accuracy -> 0.7530562347188264
